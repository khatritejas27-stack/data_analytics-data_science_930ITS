# %%
import numpy as np 
import pandas as pd

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    793     64   John  January      Q1
# 1  2023-01-02       B   West    801     21   Mary  January      Q1
# 2  2023-01-03       C  North    753     72    Bob  January      Q1
# 3  2023-01-04       D  South    974     30  Alice  January      Q1
# 4  2023-01-05       A   East    899     49   John  January      Q1
# 5  2023-01-06       B   West    791     53   Mary  January      Q1
# 6  2023-01-07       C  North    526     22    Bob  January      Q1
# 7  2023-01-08       D  South    605     35  Alice  January      Q1
# 8  2023-01-09       A   East    773     38   John  January      Q1
# 9  2023-01-10       B   West    755     60   Mary  January      Q1
# 10 2023-01-11       C  North    973     48    Bob  January      Q1
# 11 2023-01-12       D  South    341     35  Alice  January      Q1
# 12 2023-01-13       A   East    430     40   John  January      Q1
# 13 2023-01-14       B   West    412     41   Mary  January      Q1
# 14 2023-01-15       C  North    491     44    Bob  January      Q1
# 15 2023-01-16       D  South    444     83  Alice  January      Q1
# 16 2023-01-17       A   East    750     65   John  January      Q1
# 17 2023-01-18       B   West    930     88   Mary  January      Q1
# 18 2023-01-19       C  North    720     96    Bob  January      Q1
# 19 2023-01-20       D  South    916     49  Alice  January      Q1

# %%
pd.pivot_table(df,values='Sales',index="Region",columns="Product",aggfunc='median')
# Out:
# Product      A      B      C      D
# Region
# East     773.0    NaN    NaN    NaN
# North      NaN    NaN  720.0    NaN
# South      NaN    NaN    NaN  605.0
# West       NaN  791.0    NaN    NaN

# %%
pd.pivot_table(df,values='Sales',index="Region",aggfunc='median',margins=False)
# Out:
#         Sales
# Region
# East    417.0
# North   415.0
# South   600.0
# West    587.0

# %%
pd.pivot_table(df,values='Sales',index="Region",aggfunc='median',margins=True)
# Out:
#         Sales
# Region
# East    417.0
# North   415.0
# South   600.0
# West    587.0
# All     524.0

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     479.6    NaN    NaN    NaN  55.0   NaN   NaN   NaN
# North      NaN    NaN  472.2    NaN   NaN   NaN  47.8   NaN
# South      NaN    NaN    NaN  601.8   NaN   NaN   NaN  36.8
# West       NaN  587.8    NaN    NaN   NaN  61.6   NaN   NaN

# %% [markdown]
# **Cross Tabs**

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
